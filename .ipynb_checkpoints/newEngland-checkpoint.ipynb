# %%
import geopandas as gpd

filez="https://github.com/CienciaDeDatosEspacial/dataSets/raw/main/NEWENGLAND/newengland.shp"
counties=gpd.read_file(filez)

# %%
counties.plot(column='STATEFP')
# Out:
# <Axes: >

# %%
# !pip show osmnx geopandas pandas matplotlib requests shapely

# %%
import osmnx as ox
import pandas as pd

# Get fuel stations in Boston
stations = ox.features_from_place("Boston, Massachusetts, USA", 
                                tags={'amenity': 'fuel'})

# %%
type(stations)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
stations.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
stations.columns
# Out:
# Index(['geometry', 'amenity', 'addr:city', 'addr:housenumber', 'addr:postcode',
#        'addr:state', 'addr:street', 'brand', 'brand:wikidata', 'name',
#        'opening_hours', 'compressed_air', 'source', 'ref', 'website', 'shop',
#        'self_service', 'check_date', 'description', 'phone', 'internet_access',
#        'payment:mastercard', 'payment:visa', 'brand:website', 'building',
#        'fuel:diesel', 'fuel:gasoline', 'layer', 'opening_hours:signed',
#        'operator', 'source:geometry', 'building:levels', 'fuel:octane_95',
#        'type'],
#       dtype='object')

# %%
stations.reset_index(inplace=True)
stations.head()

# %%
stations[['element','geometry','brand','name']]
# Out:
#      element                                           geometry  \
# 0       node                         POINT (-71.11921 42.27983)
# 1       node                         POINT (-71.12623 42.35823)
# 2       node                         POINT (-71.05651 42.32059)
# 3       node                         POINT (-71.15482 42.29539)
# 4       node                         POINT (-71.15664 42.26192)
# 5       node                         POINT (-71.16118 42.25828)
# 6       node                         POINT (-71.15166 42.28766)
# 7       node                          POINT (-71.11332 42.3174)
# 8       node                         POINT (-71.11833 42.29594)
# 9       node                         POINT (-71.03919 42.37176)
# 10      node                         POINT (-71.02777 42.37965)
# 11      node                         POINT (-71.00924 42.38557)
# 12      node                         POINT (-71.04636 42.28384)
# 13      node                         POINT (-71.13113 42.28346)
# ...
